# %% [markdown]
# #### Guia: https://sanjayasubedi.com.np/nlp/nlp-with-python-document-clustering/

# %%
import pandas as pd
import numpy as np
import unidecode
#import mysql.connector
import re
import xlsxwriter
import datetime
from datetime import date

import nltk
from nltk.corpus import words

from sklearn.cluster import MiniBatchKMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
nltk.download('words')
nltk.download('wordnet')
nltk.download('stopwords')

stopwords = set(nltk.corpus.stopwords.words('spanish'))
include_stopwords = {'mas', 'menos', 'null', 'none'}
stopwords |= include_stopwords
print("Total spanish stopwords: {}\n".format(len(stopwords)))
stopwords_en = set(nltk.corpus.stopwords.words('english'))
print("Total english stopwords: {}\n".format(len(stopwords_en)))
# Out:
# Total spanish stopwords: 317
#
# Total english stopwords: 179
# [nltk_data] Downloading package words to C:\Users\Cristian
# [nltk_data]     Restrepo\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Cristian
# [nltk_data]     Restrepo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Cristian
# [nltk_data]     Restrepo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Funciones para normalizar y tokenizar las palabras

#función para decodificar texto
def deco(text):
    if text is None :
        pass
    else:
        text = text.decode('unicode_escape').encode('iso8859-1').decode('utf8')
    return text

def clean_skills(text):
  text = re.sub('\"', '', text)
  text = re.sub('\}', '', text)
  text = re.sub(re.compile("{..: "),  '',    text)
  
  return text

def tokenize(text):
 #Remove text in square brackets, remove punctuation and remove words containing numbers.
 text = re.sub('\[.*?¿\]\%', ' ', text)
 text = re.sub('https://', '', text)
 text = re.sub('www.', '', text)
 text = re.sub('[‘’“”…«»]', '', text)
 text = re.sub(r'["\[\]\{\}\¿]', '', text)
 text = re.sub(r'_', ' ', text) 
 #text = re.sub('[%s]' % re.escape(string.punctuation), ' ', text)
 text = re.sub('\w*\d\w*', '', text)
 text = re.sub(r'b‘\‘', '', text)

 text = re.sub('\n', ' ', text)
 text = re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)
 
 #eliminar caracteres que se repitan más de dos veces seguidas
 pattern = re.compile(r"(.)\1{2,}")
 text =pattern.sub(r"\1\1", text) 
 
 return text.split()
 
def remove_stop(tokens):
  #stopwords = ['de','para']
  return [t for t in tokens if t.lower() not in stopwords]

def remove_stop_en(tokens):
  #stopwords = ['de','para']
  return [t for t in tokens if t.lower() not in stopwords_en]
 
#def lemmatize(text):
# prueba = nlp(text)
# tokens = [word.lemma_ for word in prueba]
# return tokens
 
#def join(tokens):
# sentence = (" ").join(tokens)
# return sentence
 
pipeline = [str.lower,tokenize, remove_stop, remove_stop_en]
 
 
def prepare(text, pipeline):
  tokens = text
  for transform in pipeline:
    tokens = transform(tokens)
  return ' '.join(tokens)

# %%
df = pd.read_excel('vacantes.xlsx')
df
# Out:
#                            Id_vacante  \
# 0    967b3c3e32a879e1918dffb621079bf1
# 1                                 NaN
# 2    62465ea74438464633e3dda153a50839
# 3    9cfd169b9e2a8327ebc782b70104937a
# 4                                 NaN
# ..                                ...
# 145                         305547113
# 146                         305537998
# 147                         305547110
# 148                         305547119
# 149                         305547112
#
#                                                  Cargo  \
# 0    Supervisor of Occupational Therapy for Saudi A...
# 1                                     Dentista general
# 2         Respiratory Therapist for Saudi Arabia (M/F)
# 3    Infection Control Practitioner for Saudi Arabi...
# 4                                        iOS Developer
# ..                                                 ...
# 145                                 Frontend developer
# 146                               HR / Payroll Support
# 147                                 Frontend developer
# 148                                 Frontend developer
# 149                                 Frontend developer
#
#                                            Descripcion  Habilidades  \
# 0    Trabalho Na Hora Sobre  Contacto  Parceiros (E...          NaN
# 1    Se requiere Odontóloga general con experiencia...          NaN
# 2    Trabalho Na Hora Sobre  Contacto  Parceiros (E...          NaN
# 3    Trabalho Na Hora Sobre  Contacto  Parceiros (E...          NaN
# 4    IOS DEVELOPERLatin AmericaSweatWorks was found...          NaN
# ..                                                 ...          ...
# 145  Requisitos3 años con React, Redux y API. Poten...          NaN
# 146  Requisitos2- años de experienciaPayrollBookkee...          NaN
# 147  Requisitos3 años con React, Redux y API.Potenc...          NaN
# 148  Requisitos3 años con React, Redux y API. Poten...          NaN
# 149  Requisitos3 años con React, Redux y API.Potenc...          NaN
#
#            Nivel experiencia Tipo empleo # Solicitudes       Empresa  \
# 0                 Intermedio  CONTRACTOR           NaN  Helped Group
# 1                        NaN   FULL_TIME           NaN      merydent
# 2            Sin experiencia   FULL_TIME           NaN  Helped Group
# 3    Algo de responsabilidad  CONTRACTOR           NaN  Helped Group
# 4                        NaN   FULL_TIME           NaN    SweatWorks
# ..                       ...         ...           ...           ...
# 145          Sin experiencia   FULL_TIME           NaN         Torre
# 146          Sin experiencia   FULL_TIME           NaN         Torre
# 147          Sin experiencia   FULL_TIME           NaN         Torre
# 148          Sin experiencia   FULL_TIME           NaN         Torre
# 149          Sin experiencia   FULL_TIME           NaN         Torre
#
#                                                 Sector  \
# 0    Sanidad, bienestar y ejercicio,Profesiones méd...
# 1                                                  NaN
# 2    Sanidad, bienestar y ejercicio,Profesiones méd...
# 3    Sanidad, bienestar y ejercicio,Profesiones méd...
# 4                                                  NaN
# ..                                                 ...
# 145  Servicios y tecnologías de la información ,Sof...
# 146  Servicios y tecnologías de la información ,Sof...
# 147  Servicios y tecnologías de la información ,Sof...
# 148  Servicios y tecnologías de la información ,Sof...
# 149  Servicios y tecnologías de la información ,Sof...
#
#             Fecha publicacion                               Ubicacion  \
# 0    2021-05-03T01:15:59.000Z                  Arabia, Meta, Colombia
# 1    2021-05-03T01:08:45.000Z      Bogotá, Distrito Capital, Colombia
# 2    2021-05-03T01:07:22.000Z                  Arabia, Meta, Colombia
# 3    2021-05-03T00:50:46.000Z                  Arabia, Meta, Colombia
# 4    2021-05-03T00:41:21.000Z                                Colombia
# ..                        ...                                     ...
# 145  2021-05-02T20:55:51.000Z                 Tunja, Boyacá, Colombia
# 146  2021-05-02T20:55:51.000Z  Cartagena de Indias, Bolívar, Colombia
# 147  2021-05-02T20:55:51.000Z             Medellín, Bolívar, Colombia
# 148  2021-05-02T20:55:51.000Z         Cali, Valle del Cauca, Colombia
# 149  2021-05-02T20:55:51.000Z       Barranquilla, Atlántico, Colombia
#
#                 Ciudad Pais                                        url_vacante
# 0    Castilla La Nueva   CO  https://co.linkedin.com/jobs/view/supervisor-o...
# 1               Bogotá   CO  https://co.linkedin.com/jobs/view/dentista-gen...
# 2    Castilla La Nueva   CO  https://co.linkedin.com/jobs/view/respiratory-...
# 3    Castilla La Nueva   CO  https://co.linkedin.com/jobs/view/infection-co...
# 4                  NaN   CO  https://co.linkedin.com/jobs/view/ios-develope...
# ..                 ...  ...                                                ...
# 145             Mongua   CO  https://co.linkedin.com/jobs/view/frontend-dev...
# 146          Cartagena   CO  https://co.linkedin.com/jobs/view/hr-payroll-s...
# 147           Magangué   CO  https://co.linkedin.com/jobs/view/frontend-dev...
# 148             Yotoco   CO  https://co.linkedin.com/jobs/view/frontend-dev...
# 149       Barranquilla   CO  https://co.linkedin.com/jobs/view/frontend-dev...
#
# [150 rows x 14 columns]

# %%
df_prueba = df[['Cargo']].copy()
df_prueba.reset_index(inplace=True)
df_prueba
# Out:
#      index                                              Cargo
# 0        0  Supervisor of Occupational Therapy for Saudi A...
# 1        1                                   Dentista general
# 2        2       Respiratory Therapist for Saudi Arabia (M/F)
# 3        3  Infection Control Practitioner for Saudi Arabi...
# 4        4                                      iOS Developer
# ..     ...                                                ...
# 145    145                                 Frontend developer
# 146    146                               HR / Payroll Support
# 147    147                                 Frontend developer
# 148    148                                 Frontend developer
# 149    149                                 Frontend developer
#
# [150 rows x 2 columns]

# %%
df_prueba['Cargo'] = df_prueba['Cargo'].apply(lambda x: prepare(x, pipeline))
df_prueba
# Out:
#      index                                              Cargo
# 0        0  supervisor occupational therapy saudi arabia (...
# 1        1                                   dentista general
# 2        2           respiratory therapist saudi arabia (m/f)
# 3        3  infection control practitioner saudi arabia (m/f)
# 4        4                                      ios developer
# ..     ...                                                ...
# 145    145                                 frontend developer
# 146    146                               hr / payroll support
# 147    147                                 frontend developer
# 148    148                                 frontend developer
# 149    149                                 frontend developer
#
# [150 rows x 2 columns]

# %%
vec = TfidfVectorizer(stop_words="english")
vec.fit(df_prueba.Cargo.values)
features = vec.transform(df.Cargo.values)

# %%
# for reproducibility
random_state = 0 
cls = MiniBatchKMeans(n_clusters=10, random_state=random_state)
cls.fit(features)
# Out:
# MiniBatchKMeans(batch_size=100, compute_labels=True, init='k-means++',
#                 init_size=None, max_iter=100, max_no_improvement=10,
#                 n_clusters=10, n_init=3, random_state=0,
#                 reassignment_ratio=0.01, tol=0.0, verbose=0)

# %%
cls.predict(features)
# Out:
# array([2, 0, 2, 2, 1, 0, 7, 7, 8, 8, 8, 5, 0, 2, 7, 3, 4, 0, 0, 0, 6, 9,
#        3, 6, 0, 0, 1, 7, 7, 8, 8, 8, 5, 0, 2, 7, 3, 4, 0, 0, 0, 6, 9, 4,
#        0, 6, 3, 6, 6, 6, 0, 2, 2, 1, 0, 7, 7, 8, 8, 8, 5, 0, 2, 7, 3, 4,
#        0, 0, 0, 6, 9, 3, 6, 0, 6, 0, 2, 2, 2, 1, 0, 7, 7, 8, 8, 8, 5, 0,
#        2, 7, 3, 4, 0, 0, 0, 6, 9, 3, 6, 0, 0, 2, 2, 2, 1, 0, 7, 7, 8, 8,
#        8, 5, 0, 2, 7, 3, 4, 0, 0, 0, 6, 9, 3, 6, 0, 0, 1, 0, 7, 7, 8, 8,
#        8, 5, 0, 2, 7, 3, 4, 0, 0, 0, 6, 9, 4, 6, 0, 6, 6, 6])

# %%
# reduce the features to 2D
pca = PCA(n_components=2, random_state=random_state)
reduced_features = pca.fit_transform(features.toarray())

# reduce the cluster centers to 2D
reduced_cluster_centers = pca.transform(cls.cluster_centers_)

# %%
plt.scatter(reduced_features[:,0], reduced_features[:,1], c=cls.predict(features))
plt.scatter(reduced_cluster_centers[:, 0], reduced_cluster_centers[:,1], marker='x', s=150, c='b')
